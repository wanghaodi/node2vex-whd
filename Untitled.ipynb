# %% [markdown]
# ### node2vex : Scalable Feature Learning for Networks
# > 王颢迪 东南大学

# %%
import warnings
warnings.filterwarnings('ignore')
import argparse
import numpy as np
import networkx as nx
import gensim
import random

# %%
path = './graph/karate.edgelist'
G = nx.read_edgelist(path, nodetype=int, create_using=nx.DiGraph())
G.to_undirected()

# %%
import matplotlib.pyplot as plt
nx.draw(G, with_labels=True)
plt.show()

# %%
for node in G.nodes():
    print(node)
# Out:
# 1
# 32
# 22
# 20
# 18
# 14
# 13
# 12
# 11
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 31
# 10
# 33
# 29
# 28
# 17
# 34
# 15
# 16
# 19
# 21
# 23
# 24
# 30
# 26
# 25
# 27

# %%
print(len(G.nodes()))
# Out:
# 34
